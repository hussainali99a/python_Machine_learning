# %% [markdown]
# # step1:read data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Boston.csv")

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %% [markdown]
# # step2: check of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
df.shape
# Out:
# (506, 15)

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # step3:Eploratory data analysis(EDA)

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# black    506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'crim'}>, <Axes: title={'center': 'zn'}>,
#         <Axes: title={'center': 'indus'}>,
#         <Axes: title={'center': 'chas'}>],
#        [<Axes: title={'center': 'nox'}>, <Axes: title={'center': 'rm'}>,
#         <Axes: title={'center': 'age'}>, <Axes: title={'center': 'dis'}>],
#        [<Axes: title={'center': 'rad'}>, <Axes: title={'center': 'tax'}>,
#         <Axes: title={'center': 'ptratio'}>,
#         <Axes: title={'center': 'black'}>],
#        [<Axes: title={'center': 'lstat'}>,
#         <Axes: title={'center': 'medv'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
for i in df.columns:
    sns.kdeplot(data=df ,x=i)
    plt.show()

# %% [markdown]
# Missing values

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# outliers

# %%
for i in df.columns:
    sns.boxplot(data=df ,x=i)
    plt.show()

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
for i in ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black', 'lstat']:
    sns.boxplot(data=df,x=i,y='medv')
    plt.show()

# %% [markdown]
# Remove Ouliers

# %%
def  wisker(col):
    q1,q3 =np.percentile(col,[25,75])
    iqr = q3-q1
    lw = q1 - 1.5*iqr
    uw = q3 + 1.5*iqr
    return lw,uw

# %%
for  i in  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black', 'lstat','medv']:
    lw , uw = wisker(df[i])
    df[i] = np.where(df[i]<lw ,lw, df[i])
    df[i] = np.where(df[i]>uw ,uw, df[i])

# %%
for i in df.columns:
    sns.boxplot(data=df ,x=i)
    plt.show()

# %% [markdown]
# convert Normal distribution

# %%
sns.kdeplot(df['medv'])
# Out:
# <Axes: xlabel='medv', ylabel='Density'>

# %%
sns.kdeplot(np.log(df['medv'])) #method1 (log_normal)
# Out:
# <Axes: xlabel='medv', ylabel='Density'>

# %%
from scipy.stats import boxcox
df['medv'],l=boxcox(df['medv'])

# %%
df['medv']
# Out:
# 0       9.589019
# 1       8.897778
# 2      12.383989
# 3      12.064901
# 4      12.746310
#          ...
# 501     9.131439
# 502     8.600796
# 503     9.560784
# 504     9.015031
# 505     5.714403
# Name: medv, Length: 506, dtype: float64

# %%
sns.kdeplot(df['medv'])
# Out:
# <Axes: xlabel='medv', ylabel='Density'>

# %% [markdown]
# Model building

# %%
#without scaling
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# train ,test split
from sklearn.model_selection import train_test_split

# %%
X = df.drop('medv' , axis = 1)
y = df['medv']

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y
# Out:
# 0       9.589019
# 1       8.897778
# 2      12.383989
# 3      12.064901
# 4      12.746310
#          ...
# 501     9.131439
# 502     8.600796
# 503     9.560784
# 504     9.015031
# 505     5.714403
# Name: medv, Length: 506, dtype: float64

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.3,random_state=23)

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

X_train = pd.DataFrame(scalar.fit_transform(X_train))
X_test = pd.DataFrame(scalar.fit_transform(X_test))

# %% [markdown]
# applying other model to improve accuracy

# %%
from sklearn.preprocessing import PolynomialFeatures
poly =PolynomialFeatures(degree=2)

# %%
X_train =  poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.        ,  1.10166666, -0.60785401, ...,  0.32309862,
#         -0.38930678,  0.46908206],
#        [ 1.        , -0.60720801, -0.60785401, ...,  0.59855056,
#         -0.92149515,  1.41868268],
#        [ 1.        , -0.63089893,  1.10413187, ...,  0.38025357,
#         -0.27290077,  0.1958557 ],
#        ...,
#        [ 1.        , -0.63389011,  1.93974403, ...,  0.4971203 ,
#         -1.06525732,  2.28269327],
#        [ 1.        , -0.47992364, -0.60785401, ...,  0.04857652,
#          0.02737732,  0.01542963],
#        [ 1.        , -0.63330289,  1.43022442, ...,  0.19201774,
#         -0.31457239,  0.51534711]])

# %%
X_test
# Out:
# array([[ 1.        , -0.71807992, -0.51322807, ...,  0.40254748,
#         -0.24390952,  0.14778842],
#        [ 1.        , -0.5054041 , -0.51322807, ...,  0.67172445,
#         -0.79259621,  0.93521793],
#        [ 1.        , -0.72613584,  1.95769801, ...,  0.67172445,
#         -0.25957765,  0.10030982],
#        ...,
#        [ 1.        ,  1.93949485, -0.51322807, ...,  3.39822606,
#         -3.54069104,  3.68912863],
#        [ 1.        , -0.72787519,  1.25171913, ...,  0.34108452,
#         -0.67931326,  1.35293886],
#        [ 1.        , -0.49511271,  1.25171913, ...,  0.41480072,
#         -0.14401521,  0.05000083]])

# %%
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score ,mean_squared_error
r2_score(y_test,y_pred)
# Out:
# 0.7031475465639874

# %%
y_pred1 = model.predict(X_train)
r2_score(y_train,y_pred1)
# Out:
# 0.9058452660095639

# %% [markdown]
# ridge and lasso regression

# %%
from sklearn.linear_model import Ridge , Lasso
#Ridge regression
ridge = Ridge(alpha=1.0)
ridge.fit(X_train,y_train)
r_pred  = ridge.predict(X_test)
r = r2_score(y_test,r_pred)
print(r)
#best accuracy occurring at ridge
# Out:
# 0.7873643855924812

# %%
#Lasso regression
lasso = Lasso(alpha=0.1)
lasso.fit(X_train,y_train)
l_pred  = lasso.predict(X_test)
l = r2_score(y_test,l_pred)
print(l)
# Out:
# 0.7478042256400977
